# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('dataset_Facebook.csv')

# %%
df
# Out:
#      pagetotallikes  type  category  postmonth  postweekday  posthour  paid  \
# 0            139441     2         2         12            4         3     0
# 1            139441     3         2         12            3        10     0
# 2            139441     2         3         12            3         3     0
# 3            139441     2         2         12            2        10     1
# 4            139441     2         2         12            2         3     0
# ..              ...   ...       ...        ...          ...       ...   ...
# 367           85093     2         3          1            7        10     0
# 368           85093     2         3          1            7         2     0
# 369           81370     2         2          1            5         8     0
# 370           81370     2         1          1            5         2     0
# 371           81370     2         3          1            4        11     0
#
# ...

# %%
df1=df[['pagetotallikes','type','category','postmonth']].loc[0:10]
df1
# Out:
#     pagetotallikes  type  category  postmonth
# 0           139441     2         2         12
# 1           139441     3         2         12
# 2           139441     2         3         12
# 3           139441     2         2         12
# 4           139441     2         2         12
# 5           139441     3         2         12
# 6           139441     2         3         12
# 7           139441     2         3         12
# 8           139441     3         2         12
# 9           139441     2         3         12
# 10          139441     3         2         12

# %%
df2=df[['postweekday'	,'posthour','paid','lifetimeposttotalreach']].loc[11:20]
df2
# Out:
#     postweekday  posthour  paid  lifetimeposttotalreach
# 11            5        10     0                    3112
# 12            5        10     0                    2847
# 13            5         3     0                    2549
# 14            4         5     1                   22784
# 15            3        10     0                   10060
# 16            3         3     0                    1722
# 17            2        12     1                   53264
# 18            2         3     0                    3930
# 19            1        11     0                    1591
# 20            1         3     0                    2848

# %%
mg=pd.concat([df1,df2])
mg
# Out:
#     pagetotallikes  type  category  postmonth  postweekday  posthour  paid  \
# 0         139441.0   2.0       2.0       12.0          NaN       NaN   NaN
# 1         139441.0   3.0       2.0       12.0          NaN       NaN   NaN
# 2         139441.0   2.0       3.0       12.0          NaN       NaN   NaN
# 3         139441.0   2.0       2.0       12.0          NaN       NaN   NaN
# 4         139441.0   2.0       2.0       12.0          NaN       NaN   NaN
# 5         139441.0   3.0       2.0       12.0          NaN       NaN   NaN
# 6         139441.0   2.0       3.0       12.0          NaN       NaN   NaN
# 7         139441.0   2.0       3.0       12.0          NaN       NaN   NaN
# 8         139441.0   3.0       2.0       12.0          NaN       NaN   NaN
# 9         139441.0   2.0       3.0       12.0          NaN       NaN   NaN
# 10        139441.0   3.0       2.0       12.0          NaN       NaN   NaN
# ...

# %%
sordted=df.sort_values('pagetotallikes',ascending=True)
sordted
# Out:
#      pagetotallikes  type  category  postmonth  postweekday  posthour  paid  \
# 371           81370     2         3          1            4        11     0
# 370           81370     2         1          1            5         2     0
# 369           81370     2         2          1            5         8     0
# 366           85093     2         3          1            1         2     0
# 368           85093     2         3          1            7         2     0
# ..              ...   ...       ...        ...          ...       ...   ...
# 11           139441     2         2         12            5        10     0
# 12           139441     2         2         12            5        10     0
# 13           139441     2         2         12            5         3     0
# 7            139441     2         3         12            7         9     1
# 0            139441     2         2         12            4         3     0
#
# ...

# %%
sordted=df.sort_values('pagetotallikes',ascending=False)
sordted
# Out:
#      pagetotallikes  type  category  postmonth  postweekday  posthour  paid  \
# 0            139441     2         2         12            4         3     0
# 8            139441     3         2         12            7         3     0
# 1            139441     3         2         12            3        10     0
# 13           139441     2         2         12            5         3     0
# 12           139441     2         2         12            5        10     0
# ..              ...   ...       ...        ...          ...       ...   ...
# 367           85093     2         3          1            7        10     0
# 368           85093     2         3          1            7         2     0
# 369           81370     2         2          1            5         8     0
# 370           81370     2         1          1            5         2     0
# 371           81370     2         3          1            4        11     0
#
# ...

# %%
transposing=df.transpose()
transposing
# Out:
#                                                        0       1       2    \
# pagetotallikes                                      139441  139441  139441
# type                                                     2       3       2
# category                                                 2       2       3
# postmonth                                               12      12      12
# postweekday                                              4       3       3
# posthour                                                 3      10       3
# paid                                                     0       0       0
# lifetimeposttotalreach                                2752   10460    2413
# lifetimeposttotalimpressions                          5091   19057    4373
# lifetimeengagedusers                                   178    1457     177
# lifetimepostconsumers                                  109    1361     113
# ...

# %%
df.shape
# Out:
# (372, 19)

# %%
df.stack(level=- 1, dropna=True)
# Out:
# 0    pagetotallikes                                              139441
#      type                                                             2
#      category                                                         2
#      postmonth                                                       12
#      postweekday                                                      4
#                                                                   ...
# 371  lifetimepeoplewhohavelikedyourpageandengagedwithyourpost       370
#      comment                                                          7
#      like                                                            91
#      share                                                           38
#      totalinteractions                                              136
# Length: 7068, dtype: int64

# %%
data=np.array([1,2,3,4,5,6])
data
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
reshapedata=data.reshape((3,2))
reshapedata
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])
